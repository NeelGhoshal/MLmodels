# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()

# %%
dir(iris)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target', 'target_names']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target']=iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                  5.1               3.5  ...               0.2       0
# 1                  4.9               3.0  ...               0.2       0
# 2                  4.7               3.2  ...               0.2       0
# 3                  4.6               3.1  ...               0.2       0
# 4                  5.0               3.6  ...               0.2       0
# ..                 ...               ...  ...               ...     ...
# 145                6.7               3.0  ...               2.3       2
# 146                6.3               2.5  ...               1.9       2
# 147                6.5               3.0  ...               2.0       2
# 148                6.2               3.4  ...               2.3       2
# 149                5.9               3.0  ...               1.8       2
#
# [150 rows x 5 columns]

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df[df.target==1].head() #amt of rows for which target variable is 1
# Out:
#     sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 50                7.0               3.2  ...               1.4       1
# 51                6.4               3.2  ...               1.5       1
# 52                6.9               3.1  ...               1.5       1
# 53                5.5               2.3  ...               1.3       1
# 54                6.5               2.8  ...               1.5       1
#
# [5 rows x 5 columns]

# %%
df['flower_name']=df.target.apply(lambda x:iris.target_names[x]) #uses the df target and puts target names value in correlation with it i.e. basically creates a new column from a pre existing column
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  target  flower_name
# 0                5.1               3.5  ...       0       setosa
# 1                4.9               3.0  ...       0       setosa
# 2                4.7               3.2  ...       0       setosa
# 3                4.6               3.1  ...       0       setosa
# 4                5.0               3.6  ...       0       setosa
#
# [5 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df0=df[df.target==0]
df1=df[df.target==1]
df3=df[df.target==2]

# %%
df0.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  target  flower_name
# 0                5.1               3.5  ...       0       setosa
# 1                4.9               3.0  ...       0       setosa
# 2                4.7               3.2  ...       0       setosa
# 3                4.6               3.1  ...       0       setosa
# 4                5.0               3.6  ...       0       setosa
#
# [5 rows x 6 columns]

# %%
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.scatter(df0['sepal length (cm)'],df0['sepal width (cm)'],color='green')
plt.scatter(df1['sepal length (cm)'],df1['sepal width (cm)'],color='blue')

# %%
plt.xlabel('petal length')
plt.ylabel('petal width')
plt.scatter(df0['petal length (cm)'],df0['petal width (cm)'],color='green')
plt.scatter(df1['petal length (cm)'],df1['petal width (cm)'],color='blue')

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['target','flower_name'],axis='columns')

# %%
y=df.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 120

# %%
from sklearn.svm import SVC
model=SVC() #we can change the parameters inside SVC , eg model=SVC(C=10) etc.
model.fit(x_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model.score(x_test,y_test)
# Out:
# 0.9
