# %% [markdown]
# ![Screenshot 2021-07-11 001427.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-07-11 001810.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-07-11 001918.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-07-11 002027.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-07-11 002142.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-07-11 002341.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2021-07-11 002701.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2021-07-11 002856.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2021-07-11 003120.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("homeprices_banglore.csv")
df.sample(5)
# Out:
#     area  bedrooms  price
# 5   1170         2   38.0
# 11  2785         4  140.0
# 3   1521         3   75.0
# 19   800         1   32.0
# 2   1440         3   62.0

# %%
#scaling the data
from sklearn import preprocessing

sx=preprocessing.MinMaxScaler()
sy=preprocessing.MinMaxScaler()

scaled_X=sx.fit_transform(df.drop('price',axis='columns'))
scaled_X
# Out:
# array([[0.08827586, 0.25      ],
#        [0.62068966, 0.75      ],
#        [0.22068966, 0.5       ],
#        [0.24862069, 0.5       ],
#        [0.13793103, 0.25      ],
#        [0.12758621, 0.25      ],
#        [0.6662069 , 0.75      ],
#        [0.86206897, 0.75      ],
#        [0.17586207, 0.5       ],
#        [1.        , 1.        ],
#        [0.34482759, 0.5       ],
#        [0.68448276, 0.75      ],
#        [0.06896552, 0.25      ],
#        [0.10344828, 0.25      ],
#        [0.5       , 0.5       ],
#        [0.12931034, 0.25      ],
#        [0.13103448, 0.5       ],
#        [0.25517241, 0.5       ],
#        [0.67931034, 0.5       ],
#        [0.        , 0.        ]])

# %%
scaled_y=sx.fit_transform(df['price'].values.reshape(df.shape[0],1))  #reshaped to fit a 2 dimensional array format

scaled_y
# Out:
# array([[0.05237037],
#        [0.65185185],
#        [0.22222222],
#        [0.31851852],
#        [0.14074074],
#        [0.04444444],
#        [0.76296296],
#        [0.91111111],
#        [0.13333333],
#        [1.        ],
#        [0.37037037],
#        [0.8       ],
#        [0.04444444],
#        [0.05925926],
#        [0.51111111],
#        [0.07407407],
#        [0.11851852],
#        [0.20740741],
#        [0.51851852],
#        [0.        ]])

# %%
def batch_gradient_descent(X,y_true,epochs,learning_rate=0.01):
  number_of_features=x.shape[1]

  w=np.ones(shape=(number_of_features)) #w1,w2,... for number of features
  b=0
  total_samples=X.shape[0]

  for i in range(epochs):
    y_predicted=

# %%
#testing out the equations with eg numbers
w=np.ones(shape=(2))
scaled_X.T #transpose of scaled_X
# Out:
# array([[0.08827586, 0.62068966, 0.22068966, 0.24862069, 0.13793103,
#         0.12758621, 0.6662069 , 0.86206897, 0.17586207, 1.        ,
#         0.34482759, 0.68448276, 0.06896552, 0.10344828, 0.5       ,
#         0.12931034, 0.13103448, 0.25517241, 0.67931034, 0.        ],
#        [0.25      , 0.75      , 0.5       , 0.5       , 0.25      ,
#         0.25      , 0.75      , 0.75      , 0.5       , 1.        ,
#         0.5       , 0.75      , 0.25      , 0.25      , 0.5       ,
#         0.25      , 0.5       , 0.5       , 0.5       , 0.        ]])
