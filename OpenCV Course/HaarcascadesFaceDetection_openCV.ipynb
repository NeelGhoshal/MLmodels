# %%
#diff from face recog (only detects that there is a face)
#uses classifier
#harcascades models are present on openCV github
#we are using harcascade_frontalface_default_xml file(33000 lines of code)
#go to raw button
#ctrl c
#make a xml file on vscode
#now save and use the classifier
