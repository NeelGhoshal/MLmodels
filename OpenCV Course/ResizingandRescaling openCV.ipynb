# %%
import cv2 as cv
img=cv.imread('nature.jpeg')
cv.imshow(img)

def rescaleFrame(frame,scale=0.75): #works for imgs,vids and live video
  width=int(frame.shape[1] * scale) #frame.shape[1] means the original width
  height=int(frame.shape[0] * scale)
  dimensions=(width,height)
  return cv.resize(frame,dimensions, interpolation=cv.INTER_AREA) #resizes img to a specific dimension
cv.waitkey(0)

# %%
#reading videos
capture=cv.videocapture('') #give path of video or put 0,1 etc if webcam video is to be taken
while True:
  isTrue,frame=capture.read()
  frame_resized=rescaleFrame(frames) #resizing
  
  cv.imshow('video',frame) #to show the given video playing in a pop up screen
  cv.imshow('Video Resized',frame_resized) # showing resized part(remove the upper img part to run this)
  if cv.waitkey(20) & OxFF=ord('d'):
    break  #to break the loop so it dosent go on forever
capture.release()
cv.destroyAllWindows()

# %%
#alternate method
def ChangeRes(width,height): #works only for livecam videos
  capture.set(3,width)
  capture.set(4,height) #3 and 4 here are specific indexing inside opencv (indexing to width and height, for eg , 10 is brightness)


capture=cv.videocapture('') #give path of video or put 0,1 etc if webcam video is to be taken
while True:
  isTrue,frame=capture.read()
  frame_resized=rescaleFrame(frames) #resizing
  
  cv.imshow('video',frame) #to show the given video playing in a pop up screen
  cv.imshow('Video Resized',frame_resized) # showing resized part(remove the upper img part to run this)
  if cv.waitkey(20) & OxFF=ord('d'):
    break  #to break the loop so it dosent go on forever
capture.release()
cv.destroyAllWindows()
